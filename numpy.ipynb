# %% [markdown]
# <a href="https://colab.research.google.com/github/0601ankitsagar/ML_LAB_2026-27/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
list1 =[1,2,3,4,5]
array1 = np.array(list1)
print(array1)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np
list1 =[[[1,2,3,4,5],
 [2,3,4,5,6]]]
